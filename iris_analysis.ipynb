# %% [markdown]
# # Iris Dataset Analysis
# This notebook covers data loading, exploration, analysis, and visualization using the Iris dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %% [markdown]
# ## Load the Dataset

# %%
# Load the Iris dataset
try:
    iris = load_iris()
    df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
    df['species'] = iris.target
    df['species'] = df['species'].apply(lambda x: iris.target_names[x])
    print("Dataset loaded successfully.")
except Exception as e:
    print("Error loading dataset:", e)

# %% [markdown]
# ## Preview the Dataset

# %%
df.head()

# %% [markdown]
# ## Data Types and Missing Values

# %%
print("Data Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())

# %% [markdown]
# ## Basic Statistics

# %%
df.describe()

# %% [markdown]
# ## Grouped Analysis by Species

# %%
grouped = df.groupby('species').mean()
grouped

# %% [markdown]
# ## Line Chart: Average Feature Values per Species

# %%
sns.set(style="whitegrid")
grouped.T.plot(kind='line', marker='o')
plt.title('Average Feature Values by Iris Species')
plt.xlabel('Features')
plt.ylabel('Mean Value')
plt.legend(title='Species')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar Chart: Average Petal Length per Species

# %%
sns.barplot(x='species', y='petal length (cm)', data=df)
plt.title('Average Petal Length per Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

# %% [markdown]
# ## Histogram: Sepal Length Distribution

# %%
plt.hist(df['sepal length (cm)'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Scatter Plot: Sepal Length vs Petal Length

# %%
sns.scatterplot(data=df, x='sepal length (cm)', y='petal length (cm)', hue='species')
plt.title('Sepal Length vs. Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend()
plt.show()

# %% [markdown]
# ## Observations

# %%
print("1. Setosa species generally has the smallest petal length and width.")
print("2. Virginica species has the largest values across most features.")
print("3. Sepal length and petal length show a positive correlation.")
